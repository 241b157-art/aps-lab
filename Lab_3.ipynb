# %% [markdown]
# <a href="https://colab.research.google.com/github/241b157-art/aps-lab/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
import matplotlib.pyplot as plt
def even_odd(a):
   if (a % 2) == 0:
      return 'even'
   else:
      return 'odd'

n_values = list(range(1, 101))
time_values = []

for n in n_values:
   even_odd(n)
   time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for even_odd")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)
import matplotlib.pyplot as plt
def even_oddcount_greater_than_zero(arr):
    count = 0
    for x in arr:
        if x > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    even_oddcount_greater_than_zero(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithmic time. plot graph as well similar to above example.

import matplotlib.pyplot as plt
import math

def simple_log_function(n):
    steps = 0
    if n <= 0:
        return 0
    while n > 1:
        n = n // 2
        steps += 1
    return steps

n_values = []
time_values = []

for n in range(1, 1001, 10):
    n_values.append(n)
    time_values.append(simple_log_function(n))

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(log n) Logarithmic Time Complexity")
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.

import matplotlib.pyplot as plt
def log_linear_function(n):
    if n <= 1:
        return 0
    return int(n * math.log2(n))
n_values = []
time_values = []
for n in range(1, 1001, 10):
    n_values.append(n)
    time_values.append(log_linear_function(n))

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n log n) Log-Linear Time Complexity")
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in Polynomial Time Complexity (O(n^c)). plot the graph as well, similar to above example.

import matplotlib.pyplot as plt

def polynomial_time_function(n):
    steps = 0
    for i in range(n):
        for j in range(n):
            steps += 1
    return steps

n_values = []
time_values = []
for n in range(1, 101, 1):
    n_values.append(n)
    time_values.append(polynomial_time_function(n))

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n^2) Polynomial Time Complexity")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in Exponential Time Complexity (O(c^n)). plot the graph as well, similar to above example.

import matplotlib.pyplot as plt
def fibonacci_recursive(n):
    if n <= 1:
        return n
    else:
        return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)
n_values = list(range(1, 20))
time_values = []
for n in n_values:
    time_values.append(2**n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(2^n) Exponential Time Complexity")
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure

import matplotlib.pyplot as plt
import numpy as np
import math

n_values = np.arange(1, 50)
time_O1 = [1 for _ in n_values]
time_Ologn = np.array([math.log(n) if n > 0 else 0 for n in n_values])
time_On = n_values
time_Onlogn = np.array([n * math.log(n) if n > 0 else 0 for n in n_values])
time_On2 = n_values**2
time_O2n = 2**n_values
plt.figure(figsize=(12, 8))

scale_logn = max(time_On) / max(time_Ologn) if max(time_Ologn) > 0 else 1
plt.plot(n_values, time_Ologn * scale_logn * 0.1, label='O(log n) - Scaled', linestyle='-.', color='blue')


plt.plot(n_values, time_O1, label='O(1) - Constant', linestyle='-', color='black')
plt.plot(n_values, time_On, label='O(n) - Linear', linestyle='--', color='green')

plt.plot(n_values, time_Onlogn, label='O(n log n) - Log-Linear', linestyle=':', color='purple')

plt.plot(n_values, time_On2, label='O(n^2) - Polynomial', linestyle='-', color='orange')
n_exp_values = np.arange(1, 20)
time_O2n_small = 2**n_exp_values
plt.plot(n_exp_values, time_O2n_small, label='O(2^n) - Exponential', linestyle='-', color='red')

plt.xlabel("Input Size (n)")
plt.ylabel("Relative Time Complexity")
plt.title("Comparison of Time Complexities")
plt.legend()
plt.grid(True)
plt.ylim(0, 1000)
plt.show()

# %%
# Write a function to perform quick sort and show that it has O(n log n) Time Complexity

import matplotlib.pyplot as plt
import time
import random
import math

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

def measure_quick_sort_time(n_elements):
    data = [random.randint(0, n_elements) for _ in range(n_elements)]
    start_time = time.time()
    quick_sort(data)
    end_time = time.time()
    return end_time - start_time

n_values = list(range(1, 1001, 50))
time_values = []

for n in n_values:
    num_runs = 5
    total_time = 0
    for _ in range(num_runs):
        total_time += measure_quick_sort_time(n)
    time_values.append(total_time / num_runs)
n_log_n_values = [n * math.log(n) if n > 0 else 0 for n in n_values]

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values, marker='o', label='Quick Sort Time')
plt.plot(n_values, n_log_n_values, marker='o', label='n log n')
plt.xlabel('Number of Elements')
plt.ylabel('Time (seconds)')
plt.title('Quick Sort Time vs. n log n')
plt.legend()
plt.grid(True)
plt.show()
